# %%
#Suggest ML problems in college, healthcare, shopping and describe input → output.


ideas = {
    "College": {
        "Problem": "Student Performance Prediction",
        "Input": "Attendance, Marks, Study Hours",
        "Output": "Final Grade"
    },
    "Healthcare": {
        "Problem": "Disease Prediction",
        "Input": "Age, Symptoms, Medical History",
        "Output": "Possible Disease"
    },
    "Shopping": {
        "Problem": "Product Recommendation",
        "Input": "Search History, Purchases, Ratings",
        "Output": "Recommended Products"
    }
}

for domain in ideas:
    print("\nDomain:", domain)
    print("ML Problem:", ideas[domain]["Problem"])
    print("Input  ->", ideas[domain]["Input"])
    print("Output ->", ideas[domain]["Output"])
# Out:
# Domain: College
# ML Problem: Student Performance Prediction
# Input  -> Attendance, Marks, Study Hours
# Output -> Final Grade
#
# Domain: Healthcare
# ML Problem: Disease Prediction
# Input  -> Age, Symptoms, Medical History
# Output -> Possible Disease
#
# Domain: Shopping
# ML Problem: Product Recommendation
# Input  -> Search History, Purchases, Ratings
# Output -> Recommended Products
