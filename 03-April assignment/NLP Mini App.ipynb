# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from collections import Counter
import string

# load dataset
df = pd.read_csv("news.csv")

# train model
X = df["text"]
y = df["label"]

tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(X)

model = MultinomialNB()
model.fit(X_tfidf, y)

print("=" * 50)
print("FAKE NEWS DETECTOR + KEYWORD EXTRACTOR")
print("=" * 50)

# take input
text = input("\nEnter a news sentence:\n")

# fake news prediction
text_tfidf = tfidf.transform([text])
prediction = model.predict(text_tfidf)

# keyword extraction
clean_text = text.lower()

for ch in string.punctuation:
    clean_text = clean_text.replace(ch, "")

stop_words = [
    "is", "am", "are", "the", "a", "an",
    "and", "or", "of", "to", "in", "on",
    "for", "with", "this", "that", "it",
    "was", "were", "be", "has", "have"
]

words = clean_text.split()

keywords = []

for word in words:
    if word not in stop_words:
        keywords.append(word)

freq = Counter(keywords)

# output
print("\n" + "=" * 50)
print("RESULT")
print("=" * 50)

print("\nSentence:")
print(text)

print("\nPrediction:")
print(prediction[0].upper())

print("\nTop Keywords:")

for word, count in freq.most_common(5):
    print(word, ":", count)

# print(freq)  # debug
# Out:
# ==================================================
#       NLP MULTI TOOL ASSISTANT
# ==================================================
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
#
# Invalid Choice
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
# Bot: Sorry, I don't understand that.
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
#
# Invalid Choice
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
# Bot: Sorry, I don't understand that.
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
# Bot: Sorry, I don't understand that.
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
#
# Invalid Choice
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
#
# Invalid Choice
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
#
# Invalid Choice
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
#
# Invalid Choice
#
# 1. Chatbot
# 2. Fake News Detector
# 3. Keyword Extractor
# 4. Exit
