# %%
#print NAME, FAV FOOD, DREAM COMPANY,age
name = "Mohammad Shahbaaz"
fav_food = "Briyani"
fav_company = "Google"
age = 21


print("Hey, There this is", name)
print("My favourite food is:", fav_food)
print("I aspire to work with", fav_company)
print("I am", age, "Years Old")
# Out:
# Hey, There this is Mohammad Shahbaaz
# My favourite food is: Briyani
# I aspire to work with Google
# I am 21 Years Old
